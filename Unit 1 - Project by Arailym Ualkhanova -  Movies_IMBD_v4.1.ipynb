# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from collections import Counter
from itertools import combinations

# %%
data = pd.read_csv('movie_bd_v5.xls')
data.sample(5)
# Out:
#         imdb_id    budget    revenue               original_title  \
# 185   tt2203939  40000000  196781193              The Other Woman
# 712   tt0490181   8000000    2033165            Mutant Chronicles
# 257   tt1259571  50000000  709827462  The Twilight Saga: New Moon
# 909   tt0297181  70000000   33561137                        I Spy
# 1104  tt0332379  35000000  131282949           The School of Rock
#
#                                                    cast           director  \
# 185   Cameron Diaz|Leslie Mann|Kate Upton|Don Johnso...    Nick Cassavetes
# 712   Ron Perlman|Thomas Jane|Devon Aoki|Sean Pertwe...       Simon Hunter
# 257   Kristen Stewart|Robert Pattinson|Taylor Lautne...        Chris Weitz
# 909   Eddie Murphy|Owen Wilson|Famke Janssen|Keith D...       Betty Thomas
# 1104  Jack Black|Joan Cusack|Mike White|Sarah Silver...  Richard Linklater
#
#                                                tagline  \
# 185           The oddest friends are about to get even
# ...

# %%
data.describe()
# Out:
#              budget       revenue      runtime  vote_average  release_year
# count  1.889000e+03  1.889000e+03  1889.000000   1889.000000   1889.000000
# mean   5.431083e+07  1.553653e+08   109.658549      6.140762   2007.860773
# std    4.858721e+07  2.146698e+08    18.017041      0.764763      4.468841
# min    5.000000e+06  2.033165e+06    63.000000      3.300000   2000.000000
# 25%    2.000000e+07  3.456058e+07    97.000000      5.600000   2004.000000
# 50%    3.800000e+07  8.361541e+07   107.000000      6.100000   2008.000000
# 75%    7.200000e+07  1.782626e+08   120.000000      6.600000   2012.000000
# max    3.800000e+08  2.781506e+09   214.000000      8.100000   2015.000000

# %% [markdown]
# # Предобработка

# %%
answers = {} # создадим словарь для ответов
data['profit'] = np.nan
data['release_month'] = np.nan
data['title_length'] = np.nan
data['title_words'] = np.nan
data['list_of_actors'] = np.nan
combination_count = {}
# тут другие ваши предобработки колонок например:

#the time given in the dataset is in string format.
#So we need to change this in datetime format
# ...

# %% [markdown]
# # 1. У какого фильма из списка самый большой бюджет?

# %% [markdown]
# Использовать варианты ответов в коде решения запрещено.
# Вы думаете и в жизни у вас будут варианты ответов?)

# %%
answers['1'] = '723. Pirates of the Caribbean: On Stranger Tides (tt1298650)'
# ответ верен, +

# %%
data.iloc[data.budget.idxmax()]
#Вывод информации по фильму с максимальным бюджетом
# Out:
# imdb_id                                                         tt1298650
# budget                                                          380000000
# revenue                                                        1021683000
# original_title                Pirates of the Caribbean: On Stranger Tides
# cast                    Johnny Depp|PenÃ©lope Cruz|Geoffrey Rush|Ian M...
# director                                                     Rob Marshall
# tagline                                       Live Forever Or Die Trying.
# overview                Captain Jack Sparrow crosses paths with a woma...
# runtime                                                               136
# genres                                           Adventure|Action|Fantasy
# production_companies    Walt Disney Pictures|Jerry Bruckheimer Films|M...
# release_date                                                    5/11/2011
# vote_average                                                          6.3
# ...

# %% [markdown]
# ### ВАРИАНТ 2

# %%
# можно добавлять разные варианты решения

# %% [markdown]
# # 2. Какой из фильмов самый длительный (в минутах)?

# %%
answers['2'] = '1157. Gods and Generals (tt0279111)'
# ответ верен, +

# %%
data.iloc[data.runtime.idxmax()]
#Вывод информации по самому длинному фильму
# Out:
# imdb_id                                                         tt0279111
# budget                                                           56000000
# revenue                                                          12923936
# original_title                                          Gods and Generals
# cast                    Stephen Lang|Jeff Daniels|Robert Duvall|Kevin ...
# director                                                Ronald F. Maxwell
# tagline                               The nations heart was touched by...
# overview                The film centers mostly around the personal an...
# runtime                                                               214
# genres                                                  Drama|History|War
# production_companies                   Turner Pictures|Antietam Filmworks
# release_date                                                    2/21/2003
# vote_average                                                          5.8
# ...

# %% [markdown]
# # 3. Какой из фильмов самый короткий (в минутах)?

# %%
answers['3'] = '768. Winnie the Pooh (tt1449283)'
# ответ верен, +

# %%
data.iloc[data.runtime.idxmin()]
#Вывод информации по самому короткому фильму
# Out:
# imdb_id                                                         tt1449283
# budget                                                           30000000
# revenue                                                          14460000
# original_title                                            Winnie the Pooh
# cast                    Jim Cummings|Travis Oates|Jim Cummings|Bud Luc...
# director                                        Stephen Anderson|Don Hall
# tagline                                                          Oh Pooh.
# overview                During an ordinary day in Hundred Acre Wood, W...
# runtime                                                                63
# genres                                                   Animation|Family
# production_companies    Walt Disney Pictures|Walt Disney Animation Stu...
# release_date                                                    4/13/2011
# vote_average                                                          6.8
# ...

# %% [markdown]
# # 4. Какова средняя длительность фильмов?

# %%
answers['4'] = '109.6585494970884'
# ответ верен, +

# %%
data.runtime.mean()
# Out:
# 109.6585494970884

# %% [markdown]
# # 5. Каково медианное значение длительности фильмов?

# %%
answers['5'] = '107.0'
# ответ верен, +

# %%
data.runtime.median()
# Out:
# 107.0

# %% [markdown]
# # 6. Какой самый прибыльный фильм?
# #### Внимание! Здесь и далее под «прибылью» или «убытками» понимается разность между сборами и бюджетом фильма. (прибыль = сборы - бюджет) в нашем датасете это будет (profit = revenue - budget)

# %%
data['profit'] = data['revenue'] - data['budget']
#Добавление нового столбца по прибыли
data.iloc[data.profit.idxmax()]
#Вывод максимального значения по столбцу
# Out:
# imdb_id                                                         tt0499549
# budget                                                          237000000
# revenue                                                        2781505847
# original_title                                                     Avatar
# cast                    Sam Worthington|Zoe Saldana|Sigourney Weaver|S...
# director                                                    James Cameron
# tagline                                       Enter the World of Pandora.
# overview                In the 22nd century, a paraplegic Marine is di...
# runtime                                                               162
# genres                           Action|Adventure|Fantasy|Science Fiction
# production_companies    Ingenious Film Partners|Twentieth Century Fox ...
# release_date                                                   12/10/2009
# vote_average                                                          7.1
# ...

# %%
answers['6'] = '239. Avatar (tt0499549)'
# ответ верен, +

# %% [markdown]
# # 7. Какой фильм самый убыточный?

# %%
data.iloc[data.profit.idxmin()]
# Out:
# imdb_id                                                         tt1210819
# budget                                                          255000000
# revenue                                                          89289910
# original_title                                            The Lone Ranger
# cast                    Johnny Depp|Armie Hammer|William Fichtner|Hele...
# director                                                   Gore Verbinski
# tagline                                           Never Take Off the Mask
# overview                The Texas Rangers chase down a gang of outlaws...
# runtime                                                               149
# genres                                           Action|Adventure|Western
# production_companies    Walt Disney Pictures|Jerry Bruckheimer Films|I...
# release_date                                                     7/3/2013
# vote_average                                                            6
# ...

# %%
answers['7'] = '1245. The Lone Ranger (tt1210819)'
# ответ верен, +

# %% [markdown]
# # 8. У скольких фильмов из датасета объем сборов оказался выше бюджета?

# %%
profitable_movies = data[data['revenue'] > data['budget']]
len(profitable_movies.index)
# Out:
# 1478

# %%
answers['8'] = '1478'
# ответ верен, +

# %% [markdown]
# # 9. Какой фильм оказался самым кассовым в 2008 году?

# %%
data.loc[(data['release_year'] == 2008)].sort_values('revenue', ascending = False)
#Фильтрация фильмов 2008 года и сортировка по выручке
# Out:
#        imdb_id     budget     revenue  \
# 599  tt0468569  185000000  1001921825
# 603  tt0367882  185000000   786636033
# 606  tt0441773  130000000   631744560
# 621  tt0448157  150000000   624029371
# 607  tt0795421   52000000   609841637
# ..         ...        ...         ...
# 708  tt0486674   25000000     6673422
# 673  tt0800241   15000000     5926410
# 702  tt0844286   20000000     5530764
# 711  tt0805570   15000000     3533227
# 712  tt0490181    8000000     2033165
#
#                                         original_title  \
# 599                                    The Dark Knight
# 603  Indiana Jones and the Kingdom of the Crystal S...
# 606                                      Kung Fu Panda
# 621                                            Hancock
# 607                                         Mamma Mia!
# ..                                                 ...
# 708                                 What Just Happened
# ...

# %%
answers['9'] = '599. The Dark Knight (tt0468569)'
# ответ верен, +

# %% [markdown]
# # 10. Самый убыточный фильм за период с 2012 по 2014 г. (включительно)?

# %%
movies_in_period = data.loc[(data['release_year'] < 2015) & (data['release_year'] > 2011)]
#Фильтрация фильмов по заданному периоду
new_df = movies_in_period.reset_index()  #Создание нового ДФ
new_df.iloc[s_df.profit.idxmin()]  #Поиск убыточного фильма по новому ДФ
# Out:
# index                                                                1245
# imdb_id                                                         tt1210819
# budget                                                          255000000
# revenue                                                          89289910
# original_title                                            The Lone Ranger
# cast                    Johnny Depp|Armie Hammer|William Fichtner|Hele...
# director                                                   Gore Verbinski
# tagline                                           Never Take Off the Mask
# overview                The Texas Rangers chase down a gang of outlaws...
# runtime                                                               149
# genres                                           Action|Adventure|Western
# production_companies    Walt Disney Pictures|Jerry Bruckheimer Films|I...
# release_date                                                     7/3/2013
# ...

# %%
answers['10'] = '1245. The Lone Ranger (tt1210819)'
# ответ верен, +

# %% [markdown]
# # 11. Какого жанра фильмов больше всего?

# %%
# эту задачу тоже можно решать разными подходами, попробуй реализовать разные варианты
# если будешь добавлять функцию - выноси ее в предобработку что в начале

# %% [markdown]
# ВАРИАНТ 2

# %%
sum_genres = pd.Series(data['genres'].str.cat(sep = '|').split('|'))
sum_genres.value_counts()
#Создание списка жанров и счет их кол-ва
# Out:
# Drama              782
# Comedy             683
# Thriller           596
# Action             582
# Adventure          415
# Crime              315
# Romance            308
# Family             260
# Science Fiction    248
# Fantasy            222
# Horror             176
# Mystery            168
# Animation          139
# Music               64
# History             62
# War                 58
# Western             19
# Documentary          8
# Foreign              2
# dtype: int64

# %%
answers['11'] = 'Drama'
# ответ верен, +

# %% [markdown]
# # 12. Фильмы какого жанра чаще всего становятся прибыльными?

# %%
profitable_df = data.loc[data.profit > 0].reset_index()
# Создания нового ДФ с прибыльными фильмами
sum_genres2 = pd.Series(profitable_df['genres'].str.cat(sep = '|').split('|'))
sum_genres2.value_counts()
#Создание списка жанров и счет их кол-ва
# Out:
# Drama              560
# Comedy             551
# Thriller           446
# Action             444
# Adventure          337
# Romance            242
# Crime              231
# Family             226
# Science Fiction    195
# Fantasy            188
# Horror             150
# Animation          120
# Mystery            119
# Music               47
# History             46
# War                 41
# Western             12
# Documentary          7
# dtype: int64

# %%
answers['12'] = 'Drama'
# ответ верен, +

# %% [markdown]
# # 13. У какого режиссера самые большие суммарные кассовые сбооры?

# %%
#Вариант 1
gp_director = data.groupby(['director']).sum().sort_values('revenue', ascending = False)
#Группировка по выручке
display(gp_director)
# Out:
#                        budget     revenue  runtime  vote_average  \
# director
# Peter Jackson      1288000000  6490593685     1355          58.1
# Christopher Nolan  1005000000  4167548502     1135          61.1
# David Yates         775000000  4154295625      567          29.6
# Michael Bay        1126000000  3886938960     1209          50.0
# J.J. Abrams         740000000  3579169916      633          35.1
# ...                       ...         ...      ...           ...
# David MichÃ´d        12250000     2295423      100           6.0
# Steven Shainberg     16800000     2281089      122           6.3
# Paul Schrader         7000000     2062066      104           5.9
# Keanu Reeves         25000000     2054941      105           5.6
# Simon Hunter          8000000     2033165      111           5.1
#
#                    release_year      profit  release_month  title_length  \
# director
# Peter Jackson             16059  5202593685            0.0           0.0
# ...

# %%
#Вариант 2
directors = pd.Series(0,set(data['director'].str.cat(sep = '|').split('|')))
#Создание списка режиссеров и их поиск в основном ДФ


for director in directors.index:
    directors[director] = data[data.director.str.contains(director)].revenue.sum()
directors.sort_values(ascending=False).head(1)
# Out:
# Peter Jackson    6490593685
# dtype: int64

# %%
answers['13'] = 'Peter Jackson'
# ответ верен, +

# %% [markdown]
# # 14. Какой режисер снял больше всего фильмов в стиле Action?

# %%
data_tmp = data[data.genres.str.contains("Action")]  #Создание нового ДФ с фильмами по заданному жанру


def counter(movie_bd, x):
    data_tmp = movie_bd[x].str.cat(sep='|')  #превращаем все в одну строку
    data_tmp = pd.Series(data_tmp.split('|'))  #создаем список разделяя строку по '|'
    data_tmp = data_tmp.value_counts(ascending=False)  #считаем количество элементов в строке
    return data_tmp

sum_gen = counter(data_tmp, 'director')
sum_gen[:5]
# Out:
# Robert Rodriguez      9
# Paul W.S. Anderson    7
# Michael Bay           7
# Ridley Scott          6
# Antoine Fuqua         6
# dtype: int64

# %%
answers['14'] = 'Robert Rodriguez'
# ответ верен, +

# %% [markdown]
# # 15. Фильмы с каким актером принесли самые высокие кассовые сборы в 2012 году?

# %%
movie_2012 = data.loc[data.release_year == 2012].reset_index()
actors = pd.Series(0,set(movie_2012['cast'].str.cat(sep = '|').split('|')))


for actor in actors.index:
    actors[actor] = movie_2012[movie_2012.cast.str.contains(actor)].revenue.sum()

actors.sort_values(ascending = False).head()
# Out:
# Chris Hemsworth       2027450773
# Denis Leary           1629460639
# Anne Hathaway         1522851057
# Scarlett Johansson    1519557910
# Chris Evans           1519557910
# dtype: int64

# %%
answers['15'] = 'Chris Hemsworth'
# ответ верен, +

# %% [markdown]
# # 16. Какой актер снялся в большем количестве высокобюджетных фильмов?

# %%
movie_big_budget = data.loc[data.budget>data.budget.mean()].reset_index()
actors=pd.Series(0,set(movie_big_budget['cast'].str.cat(sep='|').split('|')))


for actor in actors.index:
    actors[actor] = movie_big_budget[movie_big_budget.cast.str.contains(actor)].imdb_id.count()

actors.sort_values(ascending = False).head(1)
# Out:
# Matt Damon    18
# dtype: int64

# %%
answers['16'] = 'Matt Damon'
# ответ верен, +

# %% [markdown]
# # 17. В фильмах какого жанра больше всего снимался Nicolas Cage?

# %%
NC_movies = data[data.cast.str.contains('Nicolas Cage', na = False)]
sum_genres3 = pd.Series(NC_movies['genres'].str.cat(sep='|').split('|'))
sum_genres3.value_counts()
# Out:
# Action             17
# Thriller           15
# Drama              12
# Crime              10
# Fantasy             8
# Adventure           7
# Comedy              6
# Science Fiction     4
# Mystery             3
# Family              3
# Animation           3
# History             2
# War                 1
# Horror              1
# Romance             1
# dtype: int64

# %%
answers['17'] = 'Action'
# ответ верен, +

# %% [markdown]
# # 18. Самый убыточный фильм от Paramount Pictures

# %%
PP_movies = data[data.production_companies.str.contains('Paramount Picture', na = False)]
PP_movies.sort_values('profit', ascending=True).head(3)
# Out:
#         imdb_id     budget   revenue        original_title  \
# 925   tt0267626  100000000  35168966  K-19: The Widowmaker
# 1123  tt0300556   80000000  19480739              Timeline
# 1722  tt0435705   70000000  18211013                  Next
#
#                                                    cast         director  \
# 925   Harrison Ford|Liam Neeson|Peter Sarsgaard|Joss...  Kathryn Bigelow
# 1123  Paul Walker|Frances O'Connor|Gerard Butler|Bil...   Richard Donner
# 1722  Nicolas Cage|Julianne Moore|Jessica Biel|Thoma...     Lee Tamahori
#
#                                                 tagline  \
# 925                            Fate has found its hero.
# 1123  They had to travel into the past to save the f...
# 1722        If you can see the future, you can save it.
#
#                                                overview  runtime  \
# 925   When Russia's first nuclear submarine malfunct...      138
# 1123  A group of archaeological students become trap...      116
# ...

# %%
answers['18'] = '925. K-19: The Widowmaker (tt0267626)'
# ответ верен, +

# %% [markdown]
# # 19. Какой год стал самым успешным по суммарным кассовым сборам?

# %%
good_year = data.groupby(['release_year']).sum().sort_values('revenue', ascending = False)
display(good_year)
# Out:
#                   budget      revenue  runtime  vote_average       profit  \
# release_year
# 2015          6780630004  25449202382    13355         755.2  18668572378
# 2014          7008050000  23405862953    13444         774.5  16397812953
# 2013          7970620000  23213799791    15039         846.9  15243179791
# 2012          7002000000  23079001687    12145         682.1  16077001687
# 2011          7946550531  22676791872    15355         868.5  14730241341
# 2010          7540000000  21071204961    13592         762.1  13531204961
# 2009          6838046652  20261791024    14187         800.2  13423744372
# 2008          6588900000  18252781990    12979         731.1  11663881990
# 2007          6596495000  18162406801    14305         809.3  11565911801
# 2004          6029250000  15663430720    12014         671.3   9634180720
# 2005          6327500000  15309425558    13387         733.5   8981925558
# ...

# %%
answers['19'] = '2015'
# ответ верен, +

# %% [markdown]
# # 20. Какой самый прибыльный год для студии Warner Bros?

# %%
WB_movies = data[data.production_companies.str.contains('Warner Bros', na = False)]
WB_good_year = WB_movies.groupby(['release_year']).sum().sort_values('profit',ascending = False)
display(WB_good_year)
# Out:
#                   budget     revenue  runtime  vote_average      profit  \
# release_year
# 2014           947600000  3243064519     1576          88.9  2295464519
# 2007           982000000  3183675217     1721          95.4  2201675217
# 2008           916000000  3050595031     1366          72.0  2134595031
# 2010          1034000000  3008712985     1421          79.6  1974712985
# 2011           974000000  2845393682     1248          68.3  1871393682
# 2003           890000000  2745493377     1085          56.7  1855493377
# 2009           915500000  2737954136     1305          67.9  1822454136
# 2013           963500000  2599953400     1100          59.9  1636453400
# 2004          1100000000  2731933725     1624          78.7  1631933725
# 2005           861000000  2412980298     1193          63.0  1551980298
# 2001           923000000  2266545668     1571          83.6  1343545668
# 2012           611500000  1869520056      579          30.0  1258020056
# ...

# %%
answers['20'] = '2014'
# ответ верен, +

# %% [markdown]
# # 21. В каком месяце за все годы суммарно вышло больше всего фильмов?

# %%
data['release_month'] = data['release_date'].apply(lambda x: x[-10:x.find("/")])
sum_table=data['release_month'].value_counts()
display(sum_table)
# Out:
# 9     227
# 12    190
# 10    186
# 8     161
# 3     156
# 4     149
# 6     147
# 11    146
# 7     142
# 5     140
# 2     135
# 1     110
# Name: release_month, dtype: int64

# %%
answers['21'] = 'September'
# ответ верен, +

# %% [markdown]
# # 22. Сколько суммарно вышло фильмов летом? (за июнь, июль, август)

# %%
summer_movies = data.loc[(data['release_month'] == '6')|(data['release_month'] == '7')|(data['release_month'] == '8')]
len(summer_movies)
# Out:
# 450

# %%
answers['22'] = '450'
# ответ верен, +

# %% [markdown]
# # 23. Для какого режиссера зима – самое продуктивное время года?

# %%
data_tmp=data[(data['release_month']=='12')|(data['release_month']=='1')|(data['release_month']=='2')] 


def counter(movie_bd, x):
    data_tmp = movie_bd[x].str.cat(sep='|') #превращаем все в одну строку
    data_tmp = pd.Series(data_tmp.split('|')) #создаем список разделяя строку по '|'
    data_tmp = data_tmp.value_counts(ascending = False) #считаем количество элементов в строке
    return data_tmp


sum_gen=counter(data_tmp, 'director')
sum_gen[:5]
# Out:
# Peter Jackson        7
# Steven Soderbergh    6
# Clint Eastwood       6
# Adam Shankman        4
# Martin Scorsese      4
# dtype: int64

# %%
answers['23'] = 'Peter Jackson'
# ответ верен, +

# %% [markdown]
# # 24. Какая студия дает самые длинные названия своим фильмам по количеству символов?

# %%
data['title_length'] = data['original_title'].str.len()
companies = pd.Series(0,set(data['production_companies'].str.cat(sep = '|').split('|')))

for company in companies.index:
    companies[company] = data[data.production_companies.str.contains(company)].title_length.mean()

companies.sort_values(ascending = False).head()
# Out:
# C:\Users\AUalkhanova\anaconda3\lib\site-packages\pandas\core\strings.py:1952: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# Four By Two Productions      83.0
# Jim Henson Company, The      59.0
# Dos Corazones                47.0
# Museum Canada Productions    46.0
# Polsky Films                 46.0
# dtype: float64

# %%
answers['24'] = 'Four By Two Productions'
# ответ верен, +

# %% [markdown]
# # 25. Описание фильмов какой студии в среднем самые длинные по количеству слов?

# %%
data['title_words'] = data['overview'].str.split().str.len()
companies=pd.Series(0,set(data['production_companies'].str.cat(sep = '|').split('|')))

for company in companies.index:
    companies[company] = data[data.production_companies.str.contains(company)].title_words.mean()
    
companies.sort_values(ascending = False).head()
# Out:
# Midnight Picture Show               175.0
# Room 9 Entertainment                161.0
# 98 MPH Productions                  159.0
# Heineken Branded Entertainment      159.0
# Brookwell-McNamara Entertainment    156.0
# dtype: float64

# %%
answers['25'] = 'Midnight Picture Show'
# ответ верен, +

# %% [markdown]
# # 26. Какие фильмы входят в 1 процент лучших по рейтингу?

# %%
data_top = data.sort_values(by = 'vote_average',ascending = False)
data_top[:round(len(data_top) * 0.01)]
# Out:
#         imdb_id     budget     revenue  \
# 599   tt0468569  185000000  1001921825
# 118   tt0816692  165000000   621752480
# 125   tt2084970   14000000   233555708
# 9     tt2096673  175000000   853708609
# 34    tt3170832    6000000    35401758
# 1183  tt0993846  100000000   392000694
# 128   tt2267998   61000000   369330363
# 1191  tt2024544   20000000   187000000
# 119   tt2015381  170000000   773312399
# 1081  tt0167260   94000000  1118888979
# 1800  tt0209144    9000000    39723096
# 370   tt1375666  160000000   825500000
# 872   tt0253474   35000000   120072577
# 138   tt2278388   30000000   174600318
# 1188  tt1798709   23000000    47351251
# 28    tt1895587   20000000    88346473
# 124   tt2245084  165000000   652105443
# 177   tt2582846   12000000   305151265
# 863   tt0167261   79000000   926287400
#
#                                      original_title  \
# 599                                 The Dark Knight
# 118                                    Interstellar
# ...

# %%
answers['26'] = 'List of movies'
# ответ верен, +

# %% [markdown]
# # 27. Какие актеры чаще всего снимаются в одном фильме вместе?

# %% [markdown]
# ВАРИАНТ 2

# %%
data['list_of_actors'] = data['cast'].str.split('|')
new_list=[]

for i in data['list_of_actors']:
    for j in list(combinations(i,2)):
        new_list.append(j)

combination_count = dict(Counter(new_list))
max(combination_count, key = combination_count.get)
# Out:
# ('Daniel Radcliffe', 'Rupert Grint')

# %%
answers['27'] = 'Daniel Radcliffe, Rupert Grint'
# ответ верен, +

# %% [markdown]
# # Submission

# %%
# в конце можно посмотреть свои ответы к каждому вопросу
answers
# Out:
# {'1': '723. Pirates of the Caribbean: On Stranger Tides (tt1298650)',
#  '2': '1157. Gods and Generals (tt0279111)',
#  '3': '768. Winnie the Pooh (tt1449283)',
#  '4': '109.6585494970884',
#  '5': '107.0',
#  '6': '239. Avatar (tt0499549)',
#  '7': '1245. The Lone Ranger (tt1210819)',
#  '8': '1478',
#  '9': '599. The Dark Knight (tt0468569)',
#  '10': '1245. The Lone Ranger (tt1210819)',
#  '11': 'Drama',
#  '12': 'Drama',
#  '13': 'Peter Jackson',
#  '14': 'Robert Rodriguez',
#  '15': 'Chris Hemsworth',
#  '16': 'Matt Damon',
#  '17': 'Action',
#  '19': '2015',
#  '20': '2014',
#  '21': 'September',
#  '22': '450',
#  '23': 'Peter Jackson',
#  '24': 'Four By Two Productions',
#  '25': 'Midnight Picture Show',
#  '26': 'List of movies',
#  '27': 'Daniel Radcliffe, Rupert Grint',
#  '18': '925. K-19: The Widowmaker (tt0267626)'}

# %%
# и убедиться что ни чего не пропустил)
len(answers)
# Out:
# 27
